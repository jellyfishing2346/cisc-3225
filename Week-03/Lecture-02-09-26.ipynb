# %%
import numpy as np
l = [1, 2, 3, 4, 5]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l = [x+6 for x in l]
print(l)
# Out:
# [7, 8, 9, 10, 11, 12]

# %%
a = np.array(l)
print(type(a))
print(a.dtype)
# Out:
# <class 'numpy.ndarray'>
# int64
