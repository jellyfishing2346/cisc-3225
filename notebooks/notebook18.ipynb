# %%
import pandas as pd

# %%
df = pd.read_csv("student_data.csv")
df.head()

# %%
df.shape
df.describe()

# %%
df["passed"] = df["exam_score"] >= 65
df

# %%
df["passed"].mean()

# %%
df.groupby("hours_studied")["exam_score"].mean()

# %%
df[["hours_studied", "sleep_hours", "exam_score"]]

# %%
X = df[["hours_studied", "sleep_hours", "attendance", "assignments_completed"]]
y = df["exam_score"]

X.head()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)

model.predict([[5, 7, 80, 6]])
