# %%
import numpy as np

arr = np.array([40,10,30,20])
print(np.sort(arr))
# Out:
# [10 20 30 40]

# %%
print(arr)
# Out:
# [40 10 30 20]

# %%
arr.sort()

print(arr)
# Out:
# [10 20 30 40]

# %%
print(arr.sort())
# Out:
# None

# %%
rng = np.random.default_rng(seed=3225)
arr2 = rng.uniform(0,100,24).astype(np.int64)
print(arr2)
# Out:
# [90 95 40 82 86 92 18 75  9  7 92 61 48  2 70 81 72 81 34 85 69 21 44 51]

# %%
print(np.sort(arr2))
print(np.sort(arr2)[::-1])
# Out:
# [ 2  7  9 18 21 34 40 44 48 51 61 69 70 72 75 81 81 82 85 86 90 92 92 95]
# [95 92 92 90 86 85 82 81 81 75 72 70 69 61 51 48 44 40 34 21 18  9  7  2]

# %%
#print(arr.sort()[::-1])    # DOES NOT WORK

# %%
#equivalent to previous
print(arr2)
print(np.flip(np.sort(arr2)))
# Out:
# [90 95 40 82 86 92 18 75  9  7 92 61 48  2 70 81 72 81 34 85 69 21 44 51]
# [95 92 92 90 86 85 82 81 81 75 72 70 69 61 51 48 44 40 34 21 18  9  7  2]

# %%
#2D arrays
A = np.array([[3,1,2],[9,7,8]])

# %%
print(np.sort(A, axis=1))
# Out:
# [[1 2 3]
#  [7 8 9]]

# %%
print(np.sort(A,axis=0))
# Out:
# [[3 1 2]
#  [9 7 8]]

# %%
# very briefly
B = np.array([
    [[9,1],[4,2]],
    [[3,7],[8,6]]
])
print(B)
print(np.sort(B, axis= 2))
# Out:
# [[[9 1]
#   [4 2]]
#
#  [[3 7]
#   [8 6]]]
# [[[1 9]
#   [2 4]]
#
#  [[3 7]
#   [6 8]]]

# %%
rng = np.random.default_rng(seed=3225)
arr3 = rng.uniform(0,100,(4,4)).astype(np.int64)
print(arr3)
# Out:
# [[90 95 40 82]
#  [86 92 18 75]
#  [ 9  7 92 61]
#  [48  2 70 81]]

# %%
A = np.array([[3,1,2],[9,7,8]])

# %%
print(np.sort(arr3))
print(np.sort(arr3)[::-1])
# Out:
# [[40 82 90 95]
#  [18 75 86 92]
#  [ 7  9 61 92]
#  [ 2 48 70 81]]
# [[ 2 48 70 81]
#  [ 7  9 61 92]
#  [18 75 86 92]
#  [40 82 90 95]]

# %%
# print each row in reverse

# %%
#np.flip(np.sort(arr3))

# %%
namesarr = np.array(["Amy","Bob","Cal","Dan","Eve"])
gradesarr = np.array([94,87,96,76,80])

for n, g in zip(namesarr,gradesarr):
    print(f"{n}: {g}")
# Out:
# Amy: 94
# Bob: 87
# Cal: 96
# Dan: 76
# Eve: 80

# %%
# how to print students in order of their grades??

print(np.sort(gradesarr))
# Out:
# [76 80 87 94 96]

# %%
print(np.sort(namesarr))
# Out:
# ['Amy' 'Bob' 'Cal' 'Dan' 'Eve']

# %%
np.argsort(gradesarr)
# Out:
# array([3, 4, 1, 0, 2])

# %%
gradesarr[np.argsort(gradesarr)]
# Out:
# array([76, 80, 87, 94, 96])

# %%
namesarr[np.argsort(gradesarr)]
# Out:
# array(['Dan', 'Eve', 'Bob', 'Amy', 'Cal'], dtype='<U3')

# %%
namesarr[np.argsort(gradesarr)][::-1]
# Out:
# array(['Cal', 'Amy', 'Bob', 'Eve', 'Dan'], dtype='<U3')

# %%
namesarr[np.argsort(gradesarr)[::-1]]
# Out:
# array(['Cal', 'Amy', 'Bob', 'Eve', 'Dan'], dtype='<U3')
